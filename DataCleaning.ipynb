# %%
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')

folder_path = '/content/drive/My Drive/Sales_snapshot_data'

dataframes = []

for filename in os.listdir(folder_path):
    if filename.endswith('.xlsx'):
        file_path = os.path.join(folder_path, filename)
        df = pd.read_excel(file_path)
        dataframes.append(df)
df = pd.concat(dataframes, ignore_index=True)
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#           month    week  site  branch_id channel_id distribution_channel  \
# 0       2022007  202228  1600       1600       TGPP             Hợp đồng
# 1       2022007  202229  1100       1100       TGPP            Phát sinh
# 2       2022007  202228  1121       1100       CHTT               Bán lẻ
# 3       2022007  202229  1120       1100       CHTT               Bán lẻ
# 4       2022007  202228  1119       1100       CHTT               Bán lẻ
# ...         ...     ...   ...        ...        ...                  ...
# 831094  2022001  202204  1147       1100       CHTT               Bán lẻ
# 831095  2022001  202153  1254       1200       CHTT               Bán lẻ
# 831096  2022001  202204  1121       1100       CHTT               Bán lẻ
# 831097  2022001  202201  1810       1800       CHTT               Bán lẻ
# ...

# %%
data = df.drop_duplicates()
data
# Out:
#           month    week  site  branch_id channel_id distribution_channel  \
# 0       2022007  202228  1600       1600       TGPP             Hợp đồng
# 1       2022007  202229  1100       1100       TGPP            Phát sinh
# 2       2022007  202228  1121       1100       CHTT               Bán lẻ
# 3       2022007  202229  1120       1100       CHTT               Bán lẻ
# 4       2022007  202228  1119       1100       CHTT               Bán lẻ
# ...         ...     ...   ...        ...        ...                  ...
# 831094  2022001  202204  1147       1100       CHTT               Bán lẻ
# 831095  2022001  202153  1254       1200       CHTT               Bán lẻ
# 831096  2022001  202204  1121       1100       CHTT               Bán lẻ
# 831097  2022001  202201  1810       1800       CHTT               Bán lẻ
# 831098  2022001  202201  1131       1100       CHTT               Bán lẻ
#
#        distribution_channel_code  sold_quantity  cost_price  net_price  \
# ...

# %%
new_data = data[['month', 'week', 'distribution_channel', 'sold_quantity', 'net_price']]
new_data
# Out:
#           month    week distribution_channel  sold_quantity  net_price
# 0       2022007  202228             Hợp đồng              1     226937
# 1       2022007  202229            Phát sinh              1     246682
# 2       2022007  202228               Bán lẻ              1     142000
# 3       2022007  202229               Bán lẻ              1     328000
# 4       2022007  202228               Bán lẻ              1     196000
# ...         ...     ...                  ...            ...        ...
# 831094  2022001  202204               Bán lẻ              1      30000
# 831095  2022001  202153               Bán lẻ              1          0
# 831096  2022001  202204               Bán lẻ              2      70000
# 831097  2022001  202201               Bán lẻ              1    1189000
# 831098  2022001  202201               Bán lẻ              1     290000
#
# [825847 rows x 5 columns]

# %% [markdown]
# Modifying month column to be
# make year and month parts and combine them in the format 'YYYY-MM'
# drop month original columns

# %%
new_data['month'] = new_data['month'].astype(str)
new_data['date'] = new_data['month'].str[:4] + '-' + new_data['month'].str[5:7]
new_data.drop(columns=['month'], inplace=True)
new_data
# Out:
# <ipython-input-17-6a45fa6f50df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['month'] = new_data['month'].astype(str)
# <ipython-input-17-6a45fa6f50df>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['date'] = new_data['month'].str[:4] + '-' + new_data['month'].str[5:7]
# <ipython-input-17-6a45fa6f50df>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# For the week column

# %%
new_data['week'] = new_data['week'].astype(str)
new_data.loc[:, 'week'] = new_data['week'].str[4:6]
new_data
# Out:
# <ipython-input-18-2ae9a601c617>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['week'] = new_data['week'].astype(str)
# <ipython-input-18-2ae9a601c617>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data.loc[:, 'week'] = new_data['week'].str[4:6]
#        week distribution_channel  sold_quantity  net_price     date
# 0        28             Hợp đồng              1     226937  2022-07
# 1        29            Phát sinh              1     246682  2022-07
# ...

# %%
column_order = ['date', 'week'] + [col for col in new_data.columns if col not in ['date', 'week']]
new_data = new_data[column_order]
new_data
# Out:
#            date week distribution_channel  sold_quantity  net_price
# 0       2022-07   28             Hợp đồng              1     226937
# 1       2022-07   29            Phát sinh              1     246682
# 2       2022-07   28               Bán lẻ              1     142000
# 3       2022-07   29               Bán lẻ              1     328000
# 4       2022-07   28               Bán lẻ              1     196000
# ...         ...  ...                  ...            ...        ...
# 831094  2022-01   04               Bán lẻ              1      30000
# 831095  2022-01   53               Bán lẻ              1          0
# 831096  2022-01   04               Bán lẻ              2      70000
# 831097  2022-01   01               Bán lẻ              1    1189000
# 831098  2022-01   01               Bán lẻ              1     290000
#
# [825847 rows x 5 columns]

# %%
file_save = '/content/drive/My Drive/Sales_data.csv'
new_data.to_csv(file_save, index=False)
